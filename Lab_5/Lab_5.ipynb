# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

import numpy as np
import random

from keras.layers import LSTM, Dense
from keras import Input, Model

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import initializers

from keras.datasets import fashion_mnist

# %% [markdown]
# # Task 1

# %%
n_timesteps_in = 70
n_timesteps_out = 90

n_features_in = 1
n_features_out = 1

# %%
time_series_length = 1500
t = np.linspace(0, 5, time_series_length)

ts_output = np.sin(t) / 2 + 3 * np.sin(t * 3) +  0.8 * np.random.standard_normal(size = time_series_length)
ts_input = np.cos(t) / 2 + 4 * np.cos(t * 3) + 0.9 * np.random.standard_normal(size = time_series_length)

ts_norm_input = (ts_input - np.mean(ts_input)) / np.std(ts_input)
ts_norm_output = (ts_output - np.mean(ts_output)) / np.std(ts_output)
plt.plot(ts_norm_input, 'blue', label = 'Input data')
plt.plot(ts_norm_output,'yellow', label = 'Output data')

plt.legend()

# %%
train_size = int(len(ts_input) * 0.8)
test_size = len(ts_input) - train_size

train_input, test_input = ts_norm_input[0:train_size], ts_norm_input[train_size:len(ts_input)]
train_output, test_output = ts_norm_output[0:train_size], ts_norm_output[train_size:len(ts_input)]

# %%
seq_len = max(n_timesteps_in, n_timesteps_out)
def create_dataset():
    # train data
    train_input_data, train_output_data = [], []
    for i in range(500):
        rand_ind_train = random.randint(0, len(train_input) - seq_len)
        input_seq = ts_norm_input[rand_ind_train:rand_ind_train+n_timesteps_in]
        output_seq = ts_norm_output[rand_ind_train:rand_ind_train+n_timesteps_out]
        train_input_data.append(input_seq)
        train_output_data.append(output_seq)
    # test data
    test_input_data, test_output_data = [], []
    for i in range(5):
        rand_ind_test = random.randint(0, len(test_input) - seq_len)
        input_seq = ts_norm_input[rand_ind_test:rand_ind_test+n_timesteps_in]
        output_seq = ts_norm_output[rand_ind_test:rand_ind_test+n_timesteps_out]
        test_input_data.append(input_seq)
        test_output_data.append(output_seq)
    return np.array(train_input_data), np.array(train_output_data), np.array(test_input_data), np.array(test_output_data)

# %%
train_input_data, train_output_data, test_input_data, test_output_data = create_dataset()

# %%
plt.plot(train_input_data[0], 'blue', label = 'Input seq sample')
plt.plot(train_output_data[0], 'yellow', label = 'Output seq sample')
plt.legend()

# %%
train_input_data = np.reshape(train_input_data, (train_input_data.shape[0], n_timesteps_in, n_features_in))
train_output_data = np.reshape(train_output_data, (train_input_data.shape[0], n_timesteps_out, n_features_out))

test_input_data = np.reshape(test_input_data, (test_input_data.shape[0], n_timesteps_in, n_features_in))
test_output_data = np.reshape(test_output_data, (test_input_data.shape[0], n_timesteps_out, n_features_out))

# %%
n_units = 128

encoder_inputs = Input(shape = (n_timesteps_in, n_features_in))
encoder = LSTM(n_units, return_sequences = False, return_state = True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

decoder_inputs = Input(shape=(n_timesteps_out, n_features_out))
decoder_lstm =  LSTM(n_units, return_sequences = True, return_state = True)

decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state = [state_h, state_c])
decoder_dense = Dense(n_features_out, activation = 'linear')
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 70, 1)]      0           []
#
#  input_2 (InputLayer)           [(None, 90, 1)]      0           []
#
#  lstm (LSTM)                    [(None, 128),        66560       ['input_1[0][0]']
#                                  (None, 128),
#                                  (None, 128)]
#
#  lstm_1 (LSTM)                  [(None, 90, 128),    66560       ['input_2[0][0]',
#                                  (None, 128),                     'lstm[0][1]',
#                                  (None, 128)]                     'lstm[0][2]']
#
#  dense (Dense)                  (None, 90, 1)        129         ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 133,249
# Trainable params: 133,249
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model.compile(optimizer = 'adam', loss = 'mse')

# %%
decoder_inputs = np.zeros(train_output_data.shape)

my_callbacks = [tf.keras.callbacks.EarlyStopping(patience=5)]

model.fit([train_input_data, decoder_inputs], train_output_data, epochs = 100, batch_size = 64, validation_split = 0.2, callbacks = my_callbacks, verbose = 2)
# Out:
# Epoch 1/100
# 7/7 - 7s - loss: 1.1898 - val_loss: 1.0685 - 7s/epoch - 1s/step
# Epoch 2/100
# 7/7 - 3s - loss: 1.1516 - val_loss: 1.0695 - 3s/epoch - 401ms/step
# Epoch 3/100
# 7/7 - 3s - loss: 1.1239 - val_loss: 1.0403 - 3s/epoch - 402ms/step
# Epoch 4/100
# 7/7 - 3s - loss: 1.0478 - val_loss: 0.7859 - 3s/epoch - 397ms/step
# Epoch 5/100
# 7/7 - 3s - loss: 0.7139 - val_loss: 0.8137 - 3s/epoch - 466ms/step
# Epoch 6/100
# 7/7 - 4s - loss: 0.5669 - val_loss: 0.5553 - 4s/epoch - 513ms/step
# Epoch 7/100
# 7/7 - 4s - loss: 0.5245 - val_loss: 0.5352 - 4s/epoch - 517ms/step
# Epoch 8/100
# 7/7 - 4s - loss: 0.4355 - val_loss: 0.4988 - 4s/epoch - 519ms/step
# Epoch 9/100
# 7/7 - 4s - loss: 0.4200 - val_loss: 0.4426 - 4s/epoch - 519ms/step
# Epoch 10/100
# 7/7 - 3s - loss: 0.4237 - val_loss: 0.3252 - 3s/epoch - 371ms/step
# Epoch 11/100
# 7/7 - 1s - loss: 0.3372 - val_loss: 0.4004 - 632ms/epoch - 90ms/step
# Epoch 12/100
# 7/7 - 1s - loss: 0.3544 - val_loss: 0.3192 - 621ms/epoch - 89ms/step
# Epoch 13/100
# 7/7 - 1s - loss: 0.3079 - val_loss: 0.3045 - 608ms/epoch - 87ms/step
# Epoch 14/100
# 7/7 - 1s - loss: 0.2720 - val_loss: 0.3084 - 604ms/epoch - 86ms/step
# Epoch 15/100
# 7/7 - 1s - loss: 0.2729 - val_loss: 0.3696 - 607ms/epoch - 87ms/step
# Epoch 16/100
# 7/7 - 1s - loss: 0.3011 - val_loss: 0.3403 - 612ms/epoch - 87ms/step
# Epoch 17/100
# 7/7 - 1s - loss: 0.2789 - val_loss: 0.2850 - 610ms/epoch - 87ms/step
# Epoch 18/100
# 7/7 - 1s - loss: 0.2522 - val_loss: 0.3011 - 590ms/epoch - 84ms/step
# Epoch 19/100
# 7/7 - 1s - loss: 0.2667 - val_loss: 0.2558 - 603ms/epoch - 86ms/step
# Epoch 20/100
# 7/7 - 1s - loss: 0.2431 - val_loss: 0.2319 - 609ms/epoch - 87ms/step
# Epoch 21/100
# 7/7 - 1s - loss: 0.2270 - val_loss: 0.2453 - 612ms/epoch - 87ms/step
# Epoch 22/100
# 7/7 - 1s - loss: 0.2310 - val_loss: 0.2374 - 604ms/epoch - 86ms/step
# Epoch 23/100
# 7/7 - 1s - loss: 0.2210 - val_loss: 0.2282 - 605ms/epoch - 86ms/step
# Epoch 24/100
# 7/7 - 1s - loss: 0.2125 - val_loss: 0.2241 - 605ms/epoch - 86ms/step
# Epoch 25/100
# 7/7 - 1s - loss: 0.2008 - val_loss: 0.2763 - 600ms/epoch - 86ms/step
# Epoch 26/100
# 7/7 - 1s - loss: 0.2102 - val_loss: 0.2139 - 595ms/epoch - 85ms/step
# Epoch 27/100
# 7/7 - 1s - loss: 0.2184 - val_loss: 0.2527 - 599ms/epoch - 86ms/step
# Epoch 28/100
# 7/7 - 1s - loss: 0.2445 - val_loss: 0.2401 - 611ms/epoch - 87ms/step
# Epoch 29/100
# 7/7 - 1s - loss: 0.2147 - val_loss: 0.2739 - 621ms/epoch - 89ms/step
# Epoch 30/100
# 7/7 - 1s - loss: 0.2085 - val_loss: 0.1954 - 605ms/epoch - 86ms/step
# Epoch 31/100
# 7/7 - 1s - loss: 0.1912 - val_loss: 0.1997 - 608ms/epoch - 87ms/step
# Epoch 32/100
# 7/7 - 1s - loss: 0.1893 - val_loss: 0.2031 - 612ms/epoch - 87ms/step
# Epoch 33/100
# 7/7 - 1s - loss: 0.1910 - val_loss: 0.1829 - 606ms/epoch - 87ms/step
# Epoch 34/100
# 7/7 - 1s - loss: 0.1896 - val_loss: 0.2131 - 597ms/epoch - 85ms/step
# Epoch 35/100
# 7/7 - 1s - loss: 0.2147 - val_loss: 0.2224 - 601ms/epoch - 86ms/step
# Epoch 36/100
# 7/7 - 1s - loss: 0.1934 - val_loss: 0.2138 - 607ms/epoch - 87ms/step
# Epoch 37/100
# 7/7 - 1s - loss: 0.1876 - val_loss: 0.2160 - 598ms/epoch - 85ms/step
# Epoch 38/100
# 7/7 - 1s - loss: 0.1875 - val_loss: 0.2152 - 600ms/epoch - 86ms/step

# %%
decoder_inputs = np.zeros(test_output_data.shape)
y_pred = model.predict([test_input_data, decoder_inputs])

# %%
plt.plot(y_pred[0], 'blue', label = 'predicted')
plt.plot(test_output_data[0], 'yellow', label = 'true')

plt.legend()

# %% [markdown]
# # TASK 2

# %%
np.random.seed(1000)

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 1us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# 26435584/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
input_dim = 784
x_train = x_train.reshape(60000, input_dim)
print('input shape: ', x_train.shape[1])
x_train = (x_train.astype(np.float32) - 127.5) / 127.5
# Out:
# input shape:  784

# %%
optim = keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)

# %%
def build_discriminator():
    model =  keras.Sequential()
    model.add(layers.Dense(1024, input_dim=input_dim, kernel_initializer=initializers.RandomNormal(stddev=0.02)))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dropout(0.3))

    model.add(layers.Dense(512))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dropout(0.3))

    model.add(layers.Dense(256))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dropout(0.3))

    model.add(layers.Dense(128))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dropout(0.3))

    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=optim)
    return model

# %%
latent_dim = 100

def build_generator():
    model =  keras.Sequential()

    model.add(layers.Dense(128, input_dim=latent_dim, kernel_initializer=initializers.RandomNormal(stddev=0.02)))
    model.add(layers.LeakyReLU(alpha=0.2))

    model.add(layers.Dense(256))
    model.add(layers.LeakyReLU(alpha=0.2))

    model.add(layers.Dense(512))
    model.add(layers.LeakyReLU(alpha=0.2))

    model.add(layers.Dense(1024))
    model.add(layers.LeakyReLU(alpha=0.2))

    model.add(layers.Dense(input_dim, activation='tanh'))
    model.compile(loss='binary_crossentropy', optimizer=optim)
    return model

# %%
discriminator = build_discriminator()
generator = build_generator()

discriminator.trainable = False
gan_input = keras.Input(shape=(latent_dim,))
x = generator(gan_input)
gan_output = discriminator(x)
gan = keras.Model(inputs=gan_input, outputs=gan_output)
gan.compile(loss='binary_crossentropy', optimizer=optim)

# %%
def plot_generated_images(epoch, generator):
    num_of_images = 10
    noise = np.random.normal(0, 1, size=[num_of_images, latent_dim])
    generated_images=generator.predict(noise).reshape(num_of_images, 28, 28)
    plt.figure()
    for i in range(num_of_images):
        plt.subplot(1, 10, i+1)
        plt.imshow(generated_images[i], cmap = 'gray')
        plt.axis('off')
        plt.tight_layout()
    plt.show()

# %%
discrim_losses = []

def train_model(epochs, batch_size):
    num_batches = int(x_train.shape[0]/batch_size)
    for ep in range(epochs+1):
        for i in range(num_batches):
            noise = np.random.normal(0, 1, size=[batch_size, latent_dim])
            image_batch = x_train[np.random.randint(0, x_train.shape[0], size=batch_size)]

            generated_images = generator.predict(noise)
            X = np.concatenate([image_batch, generated_images])

            y_dis = np.zeros(2*batch_size)
            y_dis[:batch_size] = 0.9
            discriminator.trainable = True
            d_loss = discriminator.train_on_batch(X, y_dis)
            discrim_losses.append(d_loss)

            noise = np.random.normal(0, 1, size=[batch_size, latent_dim])
            y_gen = np.ones(batch_size)
            discriminator.trainable = False
            gan.train_on_batch(noise, y_gen)
        if ep % 20 == 0:
            print('epoch: ', ep)
            plot_generated_images(ep, generator)

# %%
epochs = 100
batch_size = 128
train_model(epochs, batch_size)
# Out:
# epoch:  0
# epoch:  20
# epoch:  40
# epoch:  60

# %%
plt.plot(discrim_losses)
